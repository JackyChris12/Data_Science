# %%
## imports
import pandas as pd
import numpy as np

# %%
## load dataset and chcek the fisrt 5 rows and the last 5 rows
df = pd.read_csv('students.csv')
df.head()
##df.tail()
# Out:
#    student_id           name   age gender             major  gpa  \
# 0        1001  Alice Johnson   NaN      F  Computer Science  3.8
# 1        1002      Bob Smith  22.0      M       Mathematics  3.2
# 2        1003    Carol White  21.0      F           Physics  3.9
# 3        1004    David Brown  23.0      M       Engineering  2.8
# 4        1005     Emma Davis  20.0      F           Biology  3.6
#
#    credits_completed scholarship  attendance_rate  exam_score  \
# 0                NaN         Yes               95          88
# 1               78.0          No               82          75
# 2               60.0         Yes               98          95
# 3               90.0          No               75          68
# 4               42.0         Yes               91          82
#
#    assignment_score  participation_score      city  enrollment_year  \
# 0                92                   85  New York             2022
# ...

# %%
## check random rows
df.sample(5)
# Out:
#     student_id           name   age gender             major  gpa  \
# 18        1019    Sophia Hall  21.0      F  Computer Science  3.6
# 11        1012   Liam Jackson  24.0      M         Chemistry  2.7
# 3         1004    David Brown  23.0      M       Engineering  2.8
# 16        1017    Quinn Lewis  20.0      F           Biology  3.7
# 0         1001  Alice Johnson   NaN      F  Computer Science  3.8
#
#     credits_completed scholarship  attendance_rate  exam_score  \
# 18               56.0         Yes               89          83
# 11               98.0          No               72          65
# 3                90.0          No               75          68
# 16               46.0         Yes               92          84
# 0                 NaN         Yes               95          88
#
#     assignment_score  participation_score          city  enrollment_year  \
# 18                86                   79    Washington             2021
# ...

# %%
## how to chcek data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   student_id           30 non-null     int64
#  1   name                 30 non-null     object
#  2   age                  29 non-null     float64
#  3   gender               30 non-null     object
#  4   major                30 non-null     object
#  5   gpa                  30 non-null     float64
#  6   credits_completed    29 non-null     float64
#  7   scholarship          30 non-null     object
#  8   attendance_rate      30 non-null     int64
#  9   exam_score           30 non-null     int64
#  10  assignment_score     30 non-null     int64
#  11  participation_score  30 non-null     int64
#  12  city                 30 non-null     object
#  13  enrollment_year      30 non-null     int64
#  14  graduation_status    30 non-null     object
# ...

# %%
## chceking the description of the data
df.describe()
# Out:
#         student_id        age        gpa  credits_completed  attendance_rate  \
# count    30.000000  29.000000  30.000000          29.000000        30.000000
# mean   1015.500000  21.793103   3.320000          69.724138        85.500000
# std       8.803408   1.448628   0.478071          19.815031         9.368877
# min    1001.000000  20.000000   2.400000          41.000000        68.000000
# 25%    1008.250000  21.000000   2.925000          55.000000        78.250000
# 50%    1015.500000  22.000000   3.400000          72.000000        88.000000
# 75%    1022.750000  23.000000   3.700000          88.000000        93.750000
# max    1030.000000  24.000000   4.000000          99.000000        99.000000
#
#        exam_score  assignment_score  participation_score  enrollment_year
# count   30.000000         30.000000            30.000000        30.000000
# mean    78.500000         81.600000            74.800000      2020.266667
# ...

# %%
## checking  column names
df.columns
# Out:
# Index(['student_id', 'name', 'age', 'gender', 'major', 'gpa',
#        'credits_completed', 'scholarship', 'attendance_rate', 'exam_score',
#        'assignment_score', 'participation_score', 'city', 'enrollment_year',
#        'graduation_status'],
#       dtype='object')

# %%
## checking duplicates
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# dtype: bool

# %%
## checking for null values
df.isna().sum()
# Out:
# student_id             0
# name                   0
# age                    1
# gender                 0
# major                  0
# gpa                    0
# credits_completed      1
# scholarship            0
# attendance_rate        0
# exam_score             0
# assignment_score       0
# participation_score    0
# city                   0
# enrollment_year        0
# graduation_status      0
# dtype: int64

# %%
## checking data of a specific column 
Age = df['age']
print(Age)
# Out:
# 0      NaN
# 1     22.0
# 2     21.0
# 3     23.0
# 4     20.0
# 5     24.0
# 6     21.0
# 7     22.0
# 8     20.0
# 9     23.0
# 10    21.0
# 11    24.0
# 12    20.0
# 13    22.0
# 14    21.0
# 15    23.0
# 16    20.0
# 17    24.0
# 18    21.0
# 19    22.0
# 20    20.0
# 21    23.0
# 22    21.0
# 23    24.0
# 24    20.0
# 25    22.0
# 26    21.0
# 27    23.0
# 28    20.0
# 29    24.0
# Name: age, dtype: float64

# %%
Age =df['age'].fillna(1000)
print(Age)
# Out:
# 0     1000.0
# 1       22.0
# 2       21.0
# 3       23.0
# 4       20.0
# 5       24.0
# 6       21.0
# 7       22.0
# 8       20.0
# 9       23.0
# 10      21.0
# 11      24.0
# 12      20.0
# 13      22.0
# 14      21.0
# 15      23.0
# 16      20.0
# 17      24.0
# 18      21.0
# 19      22.0
# 20      20.0
# 21      23.0
# 22      21.0
# 23      24.0
# 24      20.0
# 25      22.0
# 26      21.0
# 27      23.0
# 28      20.0
# 29      24.0
# Name: age, dtype: float64

# %%
credits_completed =df['credits_completed']
print(credits_completed )
# Out:
# 0      NaN
# 1     78.0
# 2     60.0
# 3     90.0
# 4     42.0
# 5     95.0
# 6     55.0
# 7     72.0
# 8     48.0
# 9     85.0
# 10    58.0
# 11    98.0
# 12    44.0
# 13    75.0
# 14    62.0
# 15    88.0
# 16    46.0
# 17    96.0
# 18    56.0
# 19    74.0
# 20    47.0
# 21    86.0
# 22    59.0
# 23    97.0
# 24    43.0
# 25    76.0
# 26    61.0
# 27    91.0
# 28    41.0
# 29    99.0
# Name: credits_completed, dtype: float64

# %%
credits_completed =df['credits_completed'].mean()
print(credits_completed )
# Out:
# 69.72413793103448

# %%
credits_completed =df.fillna(df['credits_completed'].mean())
print(credits_completed )
# Out:
#     student_id           name        age gender             major  gpa  \
# 0         1001  Alice Johnson  69.724138      F  Computer Science  3.8
# 1         1002      Bob Smith  22.000000      M       Mathematics  3.2
# 2         1003    Carol White  21.000000      F           Physics  3.9
# 3         1004    David Brown  23.000000      M       Engineering  2.8
# 4         1005     Emma Davis  20.000000      F           Biology  3.6
# 5         1006   Frank Miller  24.000000      M         Chemistry  2.5
# 6         1007   Grace Wilson  21.000000      F  Computer Science  3.7
# 7         1008    Henry Moore  22.000000      M       Mathematics  3.4
# 8         1009     Ivy Taylor  20.000000      F       Engineering  3.9
# 9         1010  Jack Anderson  23.000000      M           Physics  3.1
# 10        1011    Kate Thomas  21.000000      F           Biology  3.5
# 11        1012   Liam Jackson  24.000000      M         Chemistry  2.7
# ...
