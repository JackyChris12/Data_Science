# %% [markdown]
# ## Challege 1: Even Or odd

# %%
## write a function called check_number(num) that takes an integer as input and returns:
        ## "Even" if the number is evn
        ## "Odd" if the number is Odd

def check_number(num):
    if num % 2 == 0:
        return "Even"
    else:
        return "Odd"

check_number(21)
# Out:
# 'Even'

# %% [markdown]
# ## Challenge 2: Sum of List

# %%
## Write a function called sum_list(numbers) that takes a list of numbers and returns their sum without using Python's built-in sum() function.
def sum_list(numbers):
    total = 0
    for item in numbers:
        total += item
    return total
sum_list([10,20])
# Out:
# 30

# %% [markdown]
# ## Challenge 3: Reverse string

# %%
##Write a function reverse_string(text) that returns the reverse of a given string
def reverse_string(text):
    return text[::-1]
reverse_string("python")
reverse_string("Hello")
# Out:
# 'olleH'

# %% [markdown]
# ## Challenge 4: Count Vowels

# %%
## Create a function count_vowels(word) that counts how many vowels (a,e,i,o,u) are i a given word
def count_vowels(word):
    vowels = "a,e,i,o,u"
    count = 0
    for item in word:
        if item in vowels:
            count += 1
    return count
count_vowels("Education")
# Out:
# 4

# %% [markdown]
# ## Challenge 5: Factorial finder

# %%
## write a function factorial(n) that returns the factorial of a number using ȧloop (do not use recursion or the math library).
def factorial(n):
