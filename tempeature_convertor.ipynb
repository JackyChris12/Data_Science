# %%
fahrenheit =float(input("Enter the temperature in fahrenheit: "))

celcius=(fahrenheit-32)*5/9

print(f"{fahrenheit}F is equal to {celcius}C")
# Out:
# Enter the temperature in fahrenheit:  70
# 70.0F is equal to 21.11111111111111C
